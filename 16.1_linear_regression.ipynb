# %% [markdown]
# 1.  import pacakges <br>
# 2.  read file <br>
# 3.  plot dependent and independent variable
# 4.  *X*: independent variable
# 5.  *Y*: dependent varaible
# 6.  from sklearn.model_selection import train test split
# 7.   X_train,Y_train,Y_test,X_test
# 8.  import linear_model
# 10.  scatter plot cgpa and package with line plot (X_train,lr.predict(X_train))
# 11. also check with y = m*x + b

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placement.csv")

# %%
df.head(6)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99

# %%
plt.scatter(df["cgpa"],df["package"])
plt.xlabel("CGPA")
plt.ylabel("package(in lpa )")
plt.title("placement.csv")
# Out:
# Text(0.5, 1.0, 'placement.csv')

# %%
# use algo on this data and make a model so that when 
#values are given u get value of dependent variable

# %% [markdown]
# now train and test the data to check weather the values are accuracy given or not

# %%
X = df.iloc[:,0].values  # values give values in array
Y = df.iloc[:,-1].values

# %%
X,Y
# Out:
# (array([6.89, 5.12, 7.82, 7.42, 6.94, 7.89, 6.73, 6.75, 6.09, 8.31, 5.32,
#         6.61, 8.94, 6.93, 7.73, 7.25, 6.84, 5.38, 6.94, 7.48, 7.28, 6.85,
#         6.14, 6.19, 6.53, 7.28, 8.31, 5.42, 5.94, 7.15, 7.36, 8.1 , 6.96,
#         6.35, 7.34, 6.87, 5.99, 5.9 , 8.62, 7.43, 9.38, 6.89, 5.95, 7.66,
#         5.09, 7.87, 6.07, 5.84, 8.63, 8.87, 9.58, 9.26, 8.37, 6.47, 6.86,
#         8.2 , 5.84, 6.6 , 6.92, 7.56, 5.61, 5.48, 6.34, 9.16, 7.36, 7.6 ,
#         5.11, 6.51, 7.56, 7.3 , 5.79, 7.47, 7.78, 8.44, 6.85, 6.97, 6.94,
#         8.99, 6.59, 7.18, 7.63, 6.1 , 5.58, 8.44, 4.26, 4.79, 7.61, 8.09,
#         4.73, 6.42, 7.11, 6.22, 7.9 , 6.79, 5.83, 6.63, 7.11, 5.98, 7.69,
#         6.61, 7.95, 6.71, 5.13, 7.05, 7.62, 6.66, 6.13, 6.33, 7.76, 7.77,
#         8.18, 5.42, 8.58, 6.94, 5.84, 8.35, 9.04, 7.12, 7.4 , 7.39, 5.23,
#         6.5 , 5.12, 5.1 , 6.06, 7.33, 5.91, 6.78, 7.93, 7.29, 6.68, 6.37,
#         5.84, 6.05, 7.2 , 6.1 , 5.64, 7.14, 7.91, 7.19, 7.91, 6.76, 6.93,
# ...

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)
X_train1 = X_train.reshape(-1,1)
Y_train1 = Y_train.reshape(-1,1)  
X_train1,Y_train1
# Out:
# (array([[7.14],
#         [8.93],
#         [5.42],
#         [5.1 ],
#         [7.77],
#         [6.76],
#         [6.89],
#         [6.68],
#         [7.91],
#         [7.89],
#         [8.71],
#         [7.95],
#         [6.61],
#         [6.26],
#         [6.53],
#         [6.42],
#         [5.11],
#         [6.09],
#         [6.93],
#         [7.04],
#         [5.94],
#         [6.05],
#         [5.83],
#         [5.95],
#         [9.31],
#         [5.58],
#         [7.88],
#         [6.13],
#         [7.76],
#         [4.85],
#         [6.19],
#         [8.6 ],
#         [6.07],
#         [7.18],
#         [5.12],
#         [7.39],
#         [8.25],
#         [8.28],
#         [7.13],
#         [7.35],
#         [5.66],
#         [5.99],
#         [8.01],
#         [7.14],
#         [6.34],
#         [6.89],
#         [5.42],
#         [6.47],
#         [7.69],
#         [7.4 ],
#         [7.28],
#         [5.95],
#         [7.38],
#         [6.93],
#         [8.99],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
# fit is used to train the data 
lr.fit(X_train1,Y_train1)
# Out:
# LinearRegression()

# %%
X_train = pd.DataFrame(X_train1)
X_test = pd.DataFrame(X_test)
Y_test = pd.DataFrame(Y_test)
Y_train = pd.DataFrame(Y_train1)

X_train
# Out:
#         0
# 0    7.14
# 1    8.93
# 2    5.42
# 3    5.10
# 4    7.77
# ..    ...
# 155  7.66
# 156  6.14
# 157  7.78
# 158  7.25
# 159  8.65
#
# [160 rows x 1 columns]

# %%
lr.predict(X_test)

# here I'm getting data which is not getting matched with original data
# Out:
# array([[3.89111601],
#        [3.09324469],
#        [2.38464568],
#        [2.57434935],
#        [1.6537286 ],
#        [1.77647803],
#        [2.07219258],
#        [2.93143862],
#        [3.76278706],
#        [2.93701814],
#        [4.09197872],
#        [3.51170867],
#        [2.97049525],
#        [2.40138424],
#        [3.18809652],
#        [3.46707251],
#        [1.94386362],
#        [3.24389172],
#        [2.97607477],
#        [3.41685683],
#        [2.55761079],
#        [3.16577844],
#        [2.85890486],
#        [3.12114229],
#        [3.68467378],
#        [2.8700639 ],
#        [3.49497011],
#        [3.34432308],
#        [3.91901361],
#        [1.96060218],
#        [3.65119666],
#        [3.2104146 ],
#        [3.74046898],
#        [2.7863711 ],
#        [2.78079158],
#        [3.27178932],
#        [3.52844723],
#        [2.61340599],
#        [2.65804215],
#        [2.71383735]])

# %%
X_predict=lr.predict(X_train)

# %%
plt.scatter(df["cgpa"],df["package"])
plt.plot(X_train,X_predict,color = "red")
