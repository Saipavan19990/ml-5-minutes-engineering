# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles

# %%
 make_circles
# Out:
# <function sklearn.datasets._samples_generator.make_circles(n_samples=100, *, shuffle=True, noise=None, random_state=None, factor=0.8)>

# %%
X,Y = make_circles(n_samples=200,random_state=0)

# %%
X,Y
# Out:
# (array([[ 0.58262411],
#         [-1.31093021],
#         [-0.76251627],
#         ...,
#         [-0.22425893],
#         [ 0.17581895],
#         [-0.93942432]]),
#  array([  6.14952347, -14.49116004,  -3.91844936, ...,  -7.03842781,
#          -0.91593187, -10.5491968 ]))

# %%
import matplotlib.pyplot as plt 
plt.scatter(X,Y)
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
plt.show()

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# 2nd data set

# %%
import sklearn
from sklearn.dataset import make_circles
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 2
#       1 import sklearn
# ----> 2 from sklearn.dataset import make_circles
#
# ModuleNotFoundError: No module named 'sklearn.dataset'

# %%
from sklearn.datasets import make_classification

# %%
X,Y = make_classification(n_classes=2,n_features=5,n_samples=100,random_state=0)
plt.scatter(X[:,1],X[:,2],c=Y)

# %%
X[:,2],X[1:10,1]
# Out:
# (array([-2.77259276, -0.39095338,  0.14195316,  0.52106488,  0.09740017,
#          0.52389102, -1.67600381, -0.34598178,  0.39009332, -0.4664191 ,
#         -1.54079701,  1.21114529,  0.66638308, -0.46071979, -2.06998503,
#          0.1887786 ,  0.61037938,  0.23218104, -0.65240858, -1.04525337,
#         -1.5829384 , -0.15957344, -0.94444626,  1.07961859,  0.09772497,
#         -0.54286148,  0.37915174, -1.46642433, -0.48102712,  1.95591231,
#          1.02017271, -2.03068447,  1.13689136,  0.15650654, -0.13288058,
#         -0.39727181, -0.6801782 ,  0.39904635, -0.72559738,  1.49448454,
#          1.15233156,  2.06449286, -1.30652685, -0.57578797, -1.33425847,
#          0.42625873, -0.63743703,  0.48148147,  0.7811981 ,  0.69377315,
#         -0.49331988, -0.31088617, -1.38336396,  0.60884383,  0.68981816,
#         -0.39944903, -0.69204985,  2.3039167 , -0.0525673 , -0.59631404,
#          0.28634369,  2.25930895, -0.62808756, -0.04225715,  0.67690804,
#          0.78632796, -0.50681635, -0.1359497 ,  1.53637705,  0.58295368,
#          0.37005589,  1.65813068,  0.31721822, -0.81336426, -0.41004969,
#          1.30184623,  0.41605005, -0.29779088,  0.06326199, -0.46359597,
#          0.49374178, -0.11816405, -0.31932842, -1.42406091, -1.18885926,
#         -0.30901297, -0.23792173, -0.11054066,  0.08842209, -0.01702041,
#         -1.34671751, -0.955945  ,  0.91017891, -1.93627981,  0.69474914,
#         -1.06001582,  0.69153875, -0.11610394, -0.59731607, -1.15618243]),
#  array([ 0.09076044,  0.39736975,  0.69597607, -0.6157487 , -0.98073993,
#         -0.47568347, -0.29366863, -1.055126  , -0.8016903 ]))
